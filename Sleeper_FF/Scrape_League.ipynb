# %%
import pandas as pd
import requests

# %%
league =  str(307655088971718656)
url = "https://api.sleeper.app/v1/league/" + league

# %%
r = requests.get(url = url)

# %%
data = r.json() 
data
# Out:
# {'total_rosters': 10,
#  'status': 'in_season',
#  'sport': 'nfl',
#  'settings': {'waiver_type': 0,
#   'waiver_day_of_week': 2,
#   'waiver_clear_days': 2,
#   'waiver_budget': 100,
#   'type': 0,
#   'trade_review_days': 2,
#   'trade_deadline': 10,
#   'start_week': 1,
#   'reserve_slots': 0,
#   'reserve_allow_out': 1,
#   'playoff_week_start': 14,
#   'playoff_teams': 6,
#   'pick_trading': 1,
#   'offseason_adds': 0,
#   'num_teams': 10,
#   'max_keepers': 1,
#   'leg': 5,
#   'last_scored_leg': 4,
#   'last_report': 4},
#  'season_type': 'regular',
#  'season': '2018',
#  'scoring_settings': {'safe': 2.0,
#   'fum': 0.0,
#   'fum_lost': -2.0,
#   'rush_td': 6.0,
#   'pass_td': 4.0,
#   'pass_yd': 0.03999999910593033,
#   'fgm_yds_over_30': 0.10000000149011612,
#   'rush_yd': 0.10000000149011612,
#   'pts_allow_14_20': 1.0,
#   'pts_allow_35p': -4.0,
#   'rec_td': 6.0,
#   'rush_2pt': 2.0,
#   'sack': 1.0,
#   'def_st_td': 0.0,
#   'def_st_fum_rec': 0.0,
#   'st_td': 6.0,
# ...

# %%
r_url = url + '/rosters'

# %%
ros = requests.get(url=r_url)

# %%
ros.json()
# Out:
# [{'taxi': None,
#   'starters': ['4046',
#    '2168',
#    '676',
#    '3199',
#    '830',
#    '1466',
#    '1825',
#    '4981',
#    '49',
#    'HOU'],
#   'settings': {'wins': 3,
#    'waiver_position': 3,
#    'waiver_budget_used': 0,
#    'total_moves': 0,
#    'ties': 0,
#    'losses': 1,
#    'fpts_decimal': 74,
#    'fpts_against_decimal': 18,
#    'fpts_against': 520,
#    'fpts': 526},
#   'roster_id': 1,
#   'reserve': None,
#   'players': ['1466',
#    '1825',
#    '2168',
#    '2378',
#    '2430',
#    '3157',
#    '3199',
#    '4033',
#    '4039',
#    '4046',
#    '49',
#    '4981',
#    '676',
#    '830',
#    'HOU'],
#   'player_map': None,
#   'owner_id': '307654863477538816',
#   'metadata': {'allow_pn_scoring': 'off', 'allow_pn_news': 'on'},
#   'league_id': '307655088971718656',
#   'co_owners': None},
#  {'taxi': None,
#   'starters': ['829',
#    '2391',
#    '4018',
#    '1689',
#    '344',
#    '515',
#    '1067',
#    '184',
#    '17',
#    'ARI'],
# ...
